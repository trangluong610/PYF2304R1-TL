# %% [markdown]
# # Bài 1: ![image.png](attachment:image.png)

# %%
T = 6
L = 9
H = 8
diem_TB = (T + L + H)/3
print(diem_TB)
print(diem_TB >= 8)
print (6 <= diem_TB < 8)
print(diem_TB < 6)
# Out:
# 7.666666666666667
# False
# True
# False

# %% [markdown]
# # Bài 2: ![image.png](attachment:image.png)

# %%
participation_percent = 0.7
course_complete_percent = 0.85
final_exam_mark = 8.0
print(participation_percent > 0.75 and course_complete_percent > 0.8 and final_exam_mark >= 7.5)
# Out:
# False

# %% [markdown]
# # bài 3: ![image.png](attachment:image.png)

# %%
velocity_km = 33
velocity_per_minute_km = velocity_km = 33/60
velocity_per_minute_m = velocity_per_minute_km*1000
print(velocity_per_minute_m)
distance_in_72min = velocity_per_minute_km*72
print(distance_in_72min)
# Out:
# 550.0
# 39.6

# %% [markdown]
# # Bài 4: ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
d = 16
r = 10
phan_tram_tang_them = (((d + 4)*r - d*r)/(d*r))*100
print(phan_tram_tang_them)
# Out:
# 25.0

# %% [markdown]
# # Bài 5: ![image.png](attachment:image.png)

# %%
v_xemay = 36
v_xedap = 12
khoang_cach = 48
hieu_van_toc = v_xemay - v_xedap
thoi_gian = khoang_cach / hieu_van_toc
print(thoi_gian)
# Out:
# 2.0
