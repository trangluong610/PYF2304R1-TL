# %% [markdown]
# ### Pseudo-code – Chuyển độ C sang F

# %%
Start
    Input C
    F = (9*C)/5 + 32
    Display F
End

# %% [markdown]
# ### Lưu đồ

# %% [markdown]
# ![image.png](attachment:image.png)
